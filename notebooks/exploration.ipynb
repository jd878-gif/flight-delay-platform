# %%
import os
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, count, avg, sum, max, min, round, isnan, when

# Windows fix — uncomment if you see HADOOP_HOME error
# os.environ["HADOOP_HOME"] = "C:\\hadoop"

spark = SparkSession.builder \
    .appName("FlightDelay_Exploration") \
    .master("local[*]") \
    .config("spark.driver.memory", "2g") \
    .getOrCreate()

spark.sparkContext.setLogLevel("ERROR")

# Path to your raw data — adjust if your structure is different
RAW_DATA = "../data/raw/Airline_Delay_Cause.csv"

print("Spark version:", spark.version)
print("SparkSession ready.")
